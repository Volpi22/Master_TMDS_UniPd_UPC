# %%
import os
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'
import numpy as np
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision import datasets
import random
import cifar_setup
import real_vs_fake_setup
import adversarially_trained_inception_setup
from transformers import AutoImageProcessor, AutoModelForImageClassification

# %%
# Defining the loss function for the adversarial attack
criterion = nn.CrossEntropyLoss()

# %%
# Hyperparameters for the standard variant of PGD
parameters_standard = {  
    "max_iterations": 20,
    "tolerance": 1e-6,
    "epsilon": 8/255
}

# %%
def projected_gradient_wb_standard(model, image, target, hyperparams):
    """
    Inputs:
        - model (nn.Module): The target neural network model.
        - image (torch.Tensor): The original input image (C, H, W).
        - target (torch.Tensor): The target class label for the attack.
        - hyperparams (dict): A dictionary of hyperparameters containing:
            - "max_iterations" (int): The maximum number of iterations.
            - "tolerance" (float): The duality gap tolerance for convergence.
            - "epsilon" (float): The L-infinity norm bound for the perturbation.
    Outputs:
        - final_adv_image (torch.Tensor): The generated adversarial image.
        - t (int): The number of iterations performed.
        - history (dict): A dictionary with the history of objective values, and gradient norms.
        - delta_t (torch.Tensor): The final perturbation added to the image.
    """
    # Setup device and move tensors
    device = next(model.parameters()).device
    image = image.to(device)
    target = target.to(device)

    # Defining the parameters
    max_iterations = hyperparams["max_iterations"]
    epsilon = hyperparams["epsilon"]
    tolerance = hyperparams["tolerance"]
    alpha = 2/255 
    prev_loss = float('inf')

    # Initialize the adversarial image
    adv_image = image.clone().detach()

    # History trackers
    history = {'objective': [], 'gradient_norm': []}

    # Starting the Projected Gradient iterations
    for t in range(1, max_iterations + 1):
        # Create the adversarial image by adding the perturbation
        adv_image.requires_grad = True
        
        # Forward pass
        output = model(adv_image.unsqueeze(0))

        # Define the objective function to maximize: the negative cross-entropy loss
        loss = -criterion(output, target.unsqueeze(0) if target.dim() == 0 else target)
        
        # Early stopping if attack is already successful
        with torch.no_grad():
            _, pred = torch.max(output, 1)
        if pred.item() == target.item():
            print(f"Target class reached at iteration {t}")
            break

        # Backward pass to get gradients
        model.zero_grad()
        loss.backward()
        grad = adv_image.grad.data
        
        # Store history
        history['objective'].append(-loss.item())
        history['gradient_norm'].append(grad.norm().item())

        # Check for convergence
        if abs(prev_loss - (-loss.item())) < tolerance:
            print(f"Converged at iteration {t} (tolerance: {tolerance})")
            break
        prev_loss = -loss.item()

        # Update the adversarial image using the gradient sign
        adv_image = adv_image.detach() + alpha * grad.sign()
        
        # Project the perturbation back into the epsilon-ball
        perturbation = torch.clamp(adv_image - image, min=-epsilon, max=epsilon)
        
        # Add the constrained perturbation
        adv_image = (image + perturbation).detach()

    # Create the final adversarial image
    final_delta = adv_image - image
    return adv_image, t, history, final_delta

# %%
# Hyperparameters for the momentum variant of PGD
# This variant uses momentum to accelerate the convergence of the attack
parameters_momentum = {  
    "max_iterations": 20,
    "tolerance": 1e-6,
    "epsilon": 8/255,
    "beta": 0.99
}

# %%
def projected_gradient_wb_momentum(model, image, target, hyperparams):
    """
    Inputs:
        - model (nn.Module): The target neural network model.
        - image (torch.Tensor): The original input image (C, H, W).
        - target (torch.Tensor): The target class label for the attack.
        - hyperparams (dict): A dictionary of hyperparameters containing:
            - "max_iterations" (int): The maximum number of iterations.
            - "tolerance" (float): The duality gap tolerance for convergence.
            - "epsilon" (float): The L-infinity norm bound for the perturbation.
            - "beta" (float): The momentum decay factor for the attack.
    Outputs:
        - final_adv_image (torch.Tensor): The generated adversarial image.
        - t (int): The number of iterations performed.
        - history (dict): A dictionary with the history of objective values, and gradient norms.
        - delta_t (torch.Tensor): The final perturbation added to the image.
    """
    # Setup device and move tensors
    device = next(model.parameters()).device
    image = image.to(device)
    target = target.to(device)

    # Defining the parameters
    max_iterations = hyperparams["max_iterations"]
    epsilon = hyperparams["epsilon"]
    tolerance = hyperparams["tolerance"]
    alpha = 2/255 
    beta = hyperparams["beta"]
    prev_loss = float('inf')

    # Initialize the momentum term and the adversarial image
    momentum = torch.zeros_like(image, device=device)
    adv_image = image.clone().detach()

    # History trackers
    history = {'objective': [], 'gradient_norm': []}

    # Starting the Projected Gradient iterations
    for t in range(1, max_iterations + 1):
        # Create the adversarial image by adding the perturbation
        adv_image.requires_grad = True
        
        # Forward pass
        output = model(adv_image.unsqueeze(0))

        # Define the objective function to maximize: the negative cross-entropy loss
        loss = -criterion(output, target.unsqueeze(0) if target.dim() == 0 else target)
        
        # Early stopping if attack is already successful
        with torch.no_grad():
            _, pred = torch.max(output, 1)
        if pred.item() == target.item():
            print(f"Target class reached at iteration {t}")
            break

        # Backward pass to get gradients
        model.zero_grad()
        loss.backward()
        grad = adv_image.grad.data
        
        # Store history
        history['objective'].append(-loss.item())
        history['gradient_norm'].append(grad.norm().item())

        # Check for convergence
        if abs(prev_loss - (-loss.item())) < tolerance:
            print(f"Converged at iteration {t} (tolerance: {tolerance})")
            break
        prev_loss = -loss.item()

        # Computing the momentum term
        momentum = beta * momentum + (1 - beta) * grad

        # Update the adversarial image using the momentum term
        adv_image = adv_image.detach() + alpha * momentum.sign()
        
        # Project the perturbation back into the epsilon-ball
        perturbation = torch.clamp(adv_image - image, min=-epsilon, max=epsilon)
        
        # Add the constrained perturbation
        adv_image = (image + perturbation).detach()

    # Create the final adversarial image
    final_delta = adv_image - image
    return adv_image, t, history, final_delta

# %%
# Check if the script is running on macOS with Apple Silicon GPU (MPS) or on Windows/Linux with CUDA
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple Silicon GPU (MPS) on macOS.")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using NVIDIA/AMD GPU (CUDA) on Windows/Linux.")
else:
    device = torch.device("cpu")
    print("Using CPU as no GPU is available.")

print(f"Current device: {device}")

# 1. Load a pretrained ResNet50 model and set up the device
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
model.eval()
model.to(device)

# 2. Define image transformations for CIFAR-10 to be compatible with ResNet50
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# 3. Load CIFAR-10 test set
cifar10_test = datasets.CIFAR10(root='./data', train=False, download=True, transform=preprocess)
test_loader = torch.utils.data.DataLoader(cifar10_test, batch_size=1, shuffle=True)

# 4. Map CIFAR-10 classes to ImageNet indices, as ResNet50 is trained on ImageNet
cifar10_class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
cifar_to_imagenet = {
    'airplane': 404, 'automobile': 436, 'bird': 12, 'cat': 281, 'deer': 354,
    'dog': 207, 'frog': 30, 'horse': 339, 'ship': 780, 'truck': 867
}
cifar_idx_to_imagenet_idx = {i: cifar_to_imagenet[name] for i, name in enumerate(cifar10_class_names)}

# 5. Find or load <=1000 correctly classified images to use for the attack
correctly_classified_images = cifar_setup.get_correctly_classified_images(
    model=model,
    device=device,
    dataset_name='cifar10',
    num_images=100,
    model_name='resnet50'
)
# Out:
# Using Apple Silicon GPU (MPS) on macOS.
# Current device: mps
# Loading correctly classified images from ./data/correctly_classified_cifar10_resnet50.pt...
# Loaded 100 images.

# %%
# 6. Run the attack and evaluate
distortions = []
successful_attacks = 0
total_iterations = 0
images_attacked = 0
total_images_in_list = len(correctly_classified_images)
all_possible_targets = list(cifar_idx_to_imagenet_idx.values())

print(f"--- Starting Evaluation on {total_images_in_list} candidate images ---")
for i, (image, original_label) in enumerate(correctly_classified_images):
    
    # First, verify that the model correctly classifies the image before the attack.
    with torch.no_grad():
        initial_output = model(image.unsqueeze(0))
        _, initial_pred = torch.max(initial_output, 1)

    if initial_pred.item() != original_label.item():
        print(f"Skipping image {i+1}/{total_images_in_list}: Model misclassified it. (Pred: {initial_pred.item()}, Label: {original_label.item()})")
        continue
    
    images_attacked += 1

    # For a targeted attack, choose a random target class that is different from the original.
    potential_targets = [t for t in all_possible_targets if t != original_label.item()]
    random_target_idx = random.choice(potential_targets)
    target_label = torch.tensor([random_target_idx], device=device)

    adv_image, n_iter, history, delta_final = projected_gradient_wb_momentum(  # just change this function call to the standard variant for testing, same for other models 
        model, image, target_label, parameters_momentum
    )

    with torch.no_grad():
        adv_output = model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions.append(distortion)
    total_iterations += n_iter
    
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 7. Calculate and print the final results
asr = (successful_attacks / images_attacked) * 100
avg_iterations = total_iterations / images_attacked
avg_distortion = np.mean(distortions)

print("\n--- Evaluation Summary Projected Gradient (CIFAR-10) ---")
print(f"Model: ResNet50")
print(f"Dataset: CIFAR-10 ({images_attacked} images attacked)")
print(f"Epsilon: {parameters_momentum['epsilon']:.4f}") 
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations: {avg_iterations:.2f}")
print(f"Average L-inf Distortion: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images ---
# Target class reached at iteration 9
# Processed image 1/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 4
# Processed image 2/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 3/100 | Original Label: 404 | Target: 354 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 5
# Processed image 4/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 7
# Processed image 5/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 4
# Processed image 6/100 | Original Label: 207 | Target: 12 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 7
# Processed image 7/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 8/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 10
# Processed image 9/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 4
# Processed image 10/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 8
# Processed image 11/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 7
# Processed image 12/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 6
# Processed image 13/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 4
# Processed image 14/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 7
# Processed image 15/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 16/100 | Original Label: 207 | Target: 354 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 5
# Processed image 17/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 18/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 19/100 | Original Label: 404 | Target: 12 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 7
# Processed image 20/100 | Original Label: 404 | Target: 354 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 13
# Processed image 21/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 12
# Target class reached at iteration 7
# Processed image 22/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 23/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 5
# Processed image 24/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 6
# Processed image 25/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 7
# Processed image 26/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 11
# Processed image 27/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 10
# Target class reached at iteration 4
# Processed image 28/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 7
# Processed image 29/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 9
# Processed image 30/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 8
# Processed image 31/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 7
# Processed image 32/100 | Original Label: 404 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 9
# Processed image 33/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 3
# Processed image 34/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 35/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 9
# Processed image 36/100 | Original Label: 207 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 7
# Processed image 37/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 4
# Processed image 38/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 39/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 6
# Processed image 40/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 13
# Processed image 41/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 12
# Target class reached at iteration 8
# Processed image 42/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 5
# Processed image 43/100 | Original Label: 404 | Target: 867 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 5
# Processed image 44/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 45/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 46/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 47/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 7
# Processed image 48/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 49/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 5
# Processed image 50/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 9
# Processed image 51/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 5
# Processed image 52/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 6
# Processed image 53/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 8
# Processed image 54/100 | Original Label: 404 | Target: 281 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 9
# Processed image 55/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 4
# Processed image 56/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 57/100 | Original Label: 404 | Target: 780 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 5
# Processed image 58/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 5
# Processed image 59/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 6
# Processed image 60/100 | Original Label: 207 | Target: 281 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 6
# Processed image 61/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 8
# Processed image 62/100 | Original Label: 207 | Target: 281 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 5
# Processed image 63/100 | Original Label: 404 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 7
# Processed image 64/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 6
# Processed image 65/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 10
# Processed image 66/100 | Original Label: 207 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 7
# Processed image 67/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 68/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 6
# Processed image 69/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 10
# Processed image 70/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 5
# Processed image 71/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 6
# Processed image 72/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 10
# Processed image 73/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 6
# Processed image 74/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 5
# Processed image 75/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 7
# Processed image 76/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 4
# Processed image 77/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 78/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 6
# Processed image 79/100 | Original Label: 404 | Target: 354 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 4
# Processed image 80/100 | Original Label: 404 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 81/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 82/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 83/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 7
# Processed image 84/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 8
# Processed image 85/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 9
# Processed image 86/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 4
# Processed image 87/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 88/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 89/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 90/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 9
# Processed image 91/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 6
# Processed image 92/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 13
# Processed image 93/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 12
# Target class reached at iteration 7
# Processed image 94/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 7
# Processed image 95/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 4
# Processed image 96/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 97/100 | Original Label: 354 | Target: 207 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 6
# Processed image 98/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 3
# Processed image 99/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 6
# Processed image 100/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 5
#
# --- Evaluation Summary Projected Gradient (CIFAR-10) ---
# Model: ResNet50
# Dataset: CIFAR-10 (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 100.00%
# Average Iterations: 5.32
# Average L-inf Distortion: 0.0260

# %%
# Check for device
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# 1. Load the real-vs-fake model and processor
rvf_model_name = "dima806/ai_vs_real_image_detection"
rvf_processor = AutoImageProcessor.from_pretrained(rvf_model_name)
rvf_model = AutoModelForImageClassification.from_pretrained(rvf_model_name)
rvf_model.to(device)
rvf_model.eval()

# 2. Define the path to your test dataset
test_dataset_path = '/Users/gianfranco/Desktop/ODS/test'  # Replace with your actual path. The dataset can be downloaded from https://www.kaggle.com/code/dima806/cifake-ai-generated-image-detection-vit/input

# 3. Find or load 1000 correctly classified images
# This will test the function you created in real-vs-fake_setup.py
correctly_classified_rvf_images = real_vs_fake_setup.get_correctly_classified_images_real_vs_fake(
    model=rvf_model,
    processor=rvf_processor,
    device=device,
    dataset_path=test_dataset_path,
    num_images=100
)

print(f"\nRetrieved {len(correctly_classified_rvf_images)} correctly classified real-vs-fake images.")
# Out:
# Using device: mps
# Loading correctly classified images from ./data/correctly_classified_real_vs_fake_dima806_ai_vs_real_image_detection.pt...
# Loaded 100 images.
#
# Retrieved 100 correctly classified real-vs-fake images.

# %%
# 4. Run the attack and evaluate on the Real-vs-Fake dataset

# Wrapper to make the Hugging Face model compatible with the existing attack function and ensures the model output is a tensor of logits
class ModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
    def forward(self, x):
        return self.model(x).logits

wrapped_rvf_model = ModelWrapper(rvf_model)

distortions_rvf = []
successful_attacks_rvf = 0
total_iterations_rvf = 0
images_attacked_rvf = 0
total_images_in_list = len(correctly_classified_rvf_images)

print(f"--- Starting Evaluation on {total_images_in_list} candidate images (Real-vs-Fake) ---")
resize_transform = transforms.Resize((224, 224))

for i, (image, original_label) in enumerate(correctly_classified_rvf_images):
    
    # Move tensors to the correct device for the current model
    image = image.to(device)
    original_label = original_label.to(device)

    # Resize the image to match the input size of the model
    image = resize_transform(image)

    # Verify that the model correctly classifies the image before the attack
    with torch.no_grad():
        initial_output = wrapped_rvf_model(image.unsqueeze(0))
        _, initial_pred = torch.max(initial_output, 1)

    if initial_pred.item() != original_label.item():
        print(f"Skipping image {i+1}/{total_images_in_list}: Model misclassified it. (Pred: {initial_pred.item()}, Label: {original_label.item()})")
        continue
    
    images_attacked_rvf += 1

    # For a targeted attack, the target is the other class (0 -> 1, 1 -> 0)
    target_label_idx = 1 - original_label.item()
    target_label = torch.tensor([target_label_idx], device=device)

    adv_image, n_iter, history, delta_final = projected_gradient_wb_momentum(
        wrapped_rvf_model, image, target_label, parameters_momentum
    )

    with torch.no_grad():
        adv_output = wrapped_rvf_model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks_rvf += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions_rvf.append(distortion)
    total_iterations_rvf += n_iter
    
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 5. Calculate and print the final results
asr = (successful_attacks_rvf / images_attacked_rvf) * 100
avg_iterations = total_iterations_rvf / images_attacked_rvf
avg_distortion = np.mean(distortions_rvf)

print("\n--- Evaluation Summary Projected Gradient (Real-vs-Fake) ---")
print(f"Model: {rvf_model_name}")
print(f"Dataset: Real-vs-Fake ({images_attacked_rvf} images attacked)")
print(f"Epsilon: {parameters_momentum['epsilon']:.4f}")
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations: {avg_iterations:.2f}")
print(f"Average L-inf Distortion: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images (Real-vs-Fake) ---
# Target class reached at iteration 4
# Processed image 1/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 2/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 3/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 4/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 5/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 6/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 6
# Processed image 7/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 3
# Processed image 8/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 9/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 10/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 11/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 12/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 13/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 14/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 15/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 16/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 17/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 18/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 19/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 20/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 21/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 22/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 23/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 24/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 25/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 26/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 27/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 28/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 29/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 30/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 31/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 32/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 33/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 34/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 35/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 36/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 37/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 38/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 39/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 40/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 41/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 42/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 43/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 44/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 45/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 46/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 47/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 48/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 49/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 50/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 51/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 52/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 53/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 54/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 55/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 56/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 7
# Processed image 57/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 3
# Processed image 58/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 59/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 60/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 61/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 62/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 63/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 64/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 65/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 66/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 67/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 68/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 69/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 70/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 71/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 72/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 73/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 74/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 75/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 76/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 77/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 78/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 79/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 80/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 81/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 5
# Processed image 82/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 4
# Processed image 83/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 84/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 5
# Processed image 85/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 86/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 87/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 88/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 4
# Processed image 89/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 4
# Processed image 90/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0157 | Iterations: 3
# Target class reached at iteration 3
# Processed image 91/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 92/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 93/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 94/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 95/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 96/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 3
# Processed image 97/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 98/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 3
# Processed image 99/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0078 | Iterations: 2
# Target class reached at iteration 5
# Processed image 100/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0235 | Iterations: 4
#
# --- Evaluation Summary Projected Gradient (Real-vs-Fake) ---
# Model: dima806/ai_vs_real_image_detection
# Dataset: Real-vs-Fake (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 100.00%
# Average Iterations: 2.61
# Average L-inf Distortion: 0.0125

# %%
# 1. Set up the device (MPS, CUDA, or CPU)
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple Silicon GPU (MPS)")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using NVIDIA GPU (CUDA)")
else:
    device = torch.device("cpu")
    print("Using CPU")

# 2. Load the Adversarially Trained Inception v3 model
model = adversarially_trained_inception_setup.get_model(device)
model.eval()

# 3. Load the validation dataset
# The path is hardcoded in the setup script, but can be overridden
dataset = adversarially_trained_inception_setup.get_dataset()

# 4. Find correctly classified images to attack
# This will be our test set for the attack evaluation
correctly_classified_images = adversarially_trained_inception_setup.get_correctly_classified_images(
    model=model,
    device=device,
    dataset=dataset,
    num_images=100
)
# Out:
# Using Apple Silicon GPU (MPS)
# Finding model-classified images: 100%|██████████| 100/100 [00:05<00:00, 16.84it/s]
# Found 100 images to attack.

# %%
# 5. Run the attack and evaluate

distortions = []
successful_attacks = 0
total_iterations = 0
images_attacked = 0
total_images_in_list = len(correctly_classified_images)

# The Inception v3 model was trained on ImageNet, which has 1000 classes
num_classes = 1000
all_possible_targets = list(range(num_classes))

print(f"\n--- Starting Evaluation on {total_images_in_list} candidate images ---")

for i, (image, original_label) in enumerate(correctly_classified_images):
    image, original_label = image.to(device), original_label.to(device)
    
    images_attacked += 1

    # For a targeted attack, choose a random target class that is different from the original
    potential_targets = [t for t in all_possible_targets if t != original_label.item()]
        
    random_target_idx = random.choice(potential_targets)
    target_label = torch.tensor([random_target_idx], device=device)

    # Run the attack
    adv_image, n_iter, history, delta_final = projected_gradient_wb_momentum(
        model, image.squeeze(0), target_label, parameters_momentum
    )

    # Check if the attack was successful
    with torch.no_grad():
        adv_output = model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions.append(distortion)
    total_iterations += n_iter
    
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 6. Calculate and print the final results
asr = (successful_attacks / images_attacked) * 100
avg_iterations = total_iterations / images_attacked if total_iterations > 0 else 0
avg_distortion = np.mean(distortions) if distortions else 0

print("\n--- Evaluation Summary Projected Gradient (Inception v3) ---")
print(f"Model: Adversarially Trained Inception v3")
print(f"Dataset: Validation Set ({images_attacked} images attacked)")
print(f"Epsilon: {parameters_momentum['epsilon']:.4f}")
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations for all attacks: {avg_iterations:.2f}")
print(f"Average L-inf Distortion for all attacks: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images ---
# Target class reached at iteration 10
# Processed image 1/100 | Original Label: 166 | Target: 192 | Success: True | Distortion: 0.0314 | Iterations: 9
# Processed image 2/100 | Original Label: 369 | Target: 491 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 21
# Processed image 3/100 | Original Label: 693 | Target: 444 | Success: True | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 17
# Processed image 4/100 | Original Label: 565 | Target: 270 | Success: True | Distortion: 0.0314 | Iterations: 16
# Target class reached at iteration 8
# Processed image 5/100 | Original Label: 735 | Target: 78 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 17
# Processed image 6/100 | Original Label: 420 | Target: 648 | Success: True | Distortion: 0.0314 | Iterations: 16
# Processed image 7/100 | Original Label: 20 | Target: 930 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 8/100 | Original Label: 993 | Target: 293 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 9/100 | Original Label: 993 | Target: 180 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 7
# Processed image 10/100 | Original Label: 158 | Target: 333 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 8
# Processed image 11/100 | Original Label: 973 | Target: 819 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 20
# Processed image 12/100 | Original Label: 655 | Target: 116 | Success: True | Distortion: 0.0314 | Iterations: 19
# Target class reached at iteration 16
# Processed image 13/100 | Original Label: 905 | Target: 724 | Success: True | Distortion: 0.0314 | Iterations: 15
# Processed image 14/100 | Original Label: 431 | Target: 607 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 6
# Processed image 15/100 | Original Label: 122 | Target: 791 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 15
# Processed image 16/100 | Original Label: 174 | Target: 321 | Success: True | Distortion: 0.0314 | Iterations: 14
# Target class reached at iteration 10
# Processed image 17/100 | Original Label: 997 | Target: 693 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 14
# Processed image 18/100 | Original Label: 724 | Target: 791 | Success: True | Distortion: 0.0314 | Iterations: 13
# Processed image 19/100 | Original Label: 83 | Target: 817 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 12
# Processed image 20/100 | Original Label: 146 | Target: 946 | Success: True | Distortion: 0.0314 | Iterations: 11
# Target class reached at iteration 9
# Processed image 21/100 | Original Label: 838 | Target: 626 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 10
# Processed image 22/100 | Original Label: 550 | Target: 695 | Success: True | Distortion: 0.0314 | Iterations: 9
# Processed image 23/100 | Original Label: 117 | Target: 78 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 17
# Processed image 24/100 | Original Label: 664 | Target: 30 | Success: True | Distortion: 0.0314 | Iterations: 16
# Target class reached at iteration 7
# Processed image 25/100 | Original Label: 731 | Target: 720 | Success: True | Distortion: 0.0314 | Iterations: 6
# Target class reached at iteration 15
# Processed image 26/100 | Original Label: 141 | Target: 711 | Success: True | Distortion: 0.0314 | Iterations: 14
# Target class reached at iteration 20
# Processed image 27/100 | Original Label: 587 | Target: 186 | Success: True | Distortion: 0.0314 | Iterations: 19
# Target class reached at iteration 6
# Processed image 28/100 | Original Label: 740 | Target: 401 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 19
# Processed image 29/100 | Original Label: 231 | Target: 358 | Success: True | Distortion: 0.0314 | Iterations: 18
# Target class reached at iteration 9
# Processed image 30/100 | Original Label: 988 | Target: 377 | Success: True | Distortion: 0.0314 | Iterations: 8
# Target class reached at iteration 17
# Processed image 31/100 | Original Label: 299 | Target: 917 | Success: True | Distortion: 0.0314 | Iterations: 16
# Target class reached at iteration 11
# Processed image 32/100 | Original Label: 976 | Target: 810 | Success: True | Distortion: 0.0314 | Iterations: 10
# Target class reached at iteration 19
# Processed image 33/100 | Original Label: 327 | Target: 646 | Success: True | Distortion: 0.0314 | Iterations: 18
# Processed image 34/100 | Original Label: 182 | Target: 118 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 13
# Processed image 35/100 | Original Label: 851 | Target: 436 | Success: True | Distortion: 0.0314 | Iterations: 12
# Processed image 36/100 | Original Label: 576 | Target: 322 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 37/100 | Original Label: 537 | Target: 951 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 38/100 | Original Label: 343 | Target: 949 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 12
# Processed image 39/100 | Original Label: 59 | Target: 755 | Success: True | Distortion: 0.0314 | Iterations: 11
# Target class reached at iteration 14
# Processed image 40/100 | Original Label: 995 | Target: 416 | Success: True | Distortion: 0.0314 | Iterations: 13
# Processed image 41/100 | Original Label: 231 | Target: 784 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 8
# Processed image 42/100 | Original Label: 650 | Target: 777 | Success: True | Distortion: 0.0314 | Iterations: 7
# Target class reached at iteration 12
# Processed image 43/100 | Original Label: 164 | Target: 407 | Success: True | Distortion: 0.0314 | Iterations: 11
# Processed image 44/100 | Original Label: 800 | Target: 270 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 45/100 | Original Label: 795 | Target: 96 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 46/100 | Original Label: 465 | Target: 231 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 47/100 | Original Label: 357 | Target: 942 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 15
# Processed image 48/100 | Original Label: 334 | Target: 788 | Success: True | Distortion: 0.0314 | Iterations: 14
# Processed image 49/100 | Original Label: 523 | Target: 17 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 16
# Processed image 50/100 | Original Label: 520 | Target: 828 | Success: True | Distortion: 0.0314 | Iterations: 15
# Processed image 51/100 | Original Label: 234 | Target: 481 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 52/100 | Original Label: 951 | Target: 844 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 10
# Processed image 53/100 | Original Label: 532 | Target: 703 | Success: True | Distortion: 0.0314 | Iterations: 9
# Target class reached at iteration 13
# Processed image 54/100 | Original Label: 855 | Target: 867 | Success: True | Distortion: 0.0314 | Iterations: 12
# Target class reached at iteration 17
# Processed image 55/100 | Original Label: 118 | Target: 189 | Success: True | Distortion: 0.0314 | Iterations: 16
# Processed image 56/100 | Original Label: 13 | Target: 724 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 8
# Processed image 57/100 | Original Label: 819 | Target: 736 | Success: True | Distortion: 0.0314 | Iterations: 7
# Processed image 58/100 | Original Label: 457 | Target: 408 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 15
# Processed image 59/100 | Original Label: 598 | Target: 829 | Success: True | Distortion: 0.0314 | Iterations: 14
# Processed image 60/100 | Original Label: 101 | Target: 687 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 61/100 | Original Label: 910 | Target: 317 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 16
# Processed image 62/100 | Original Label: 975 | Target: 894 | Success: True | Distortion: 0.0314 | Iterations: 15
# Processed image 63/100 | Original Label: 877 | Target: 134 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 64/100 | Original Label: 47 | Target: 632 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 6
# Processed image 65/100 | Original Label: 130 | Target: 134 | Success: True | Distortion: 0.0314 | Iterations: 5
# Processed image 66/100 | Original Label: 804 | Target: 340 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 19
# Processed image 67/100 | Original Label: 455 | Target: 678 | Success: True | Distortion: 0.0314 | Iterations: 18
# Target class reached at iteration 12
# Processed image 68/100 | Original Label: 371 | Target: 826 | Success: True | Distortion: 0.0314 | Iterations: 11
# Target class reached at iteration 15
# Processed image 69/100 | Original Label: 229 | Target: 532 | Success: True | Distortion: 0.0314 | Iterations: 14
# Target class reached at iteration 17
# Processed image 70/100 | Original Label: 196 | Target: 970 | Success: True | Distortion: 0.0314 | Iterations: 16
# Processed image 71/100 | Original Label: 606 | Target: 496 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 14
# Processed image 72/100 | Original Label: 88 | Target: 503 | Success: True | Distortion: 0.0314 | Iterations: 13
# Target class reached at iteration 15
# Processed image 73/100 | Original Label: 704 | Target: 845 | Success: True | Distortion: 0.0314 | Iterations: 14
# Processed image 74/100 | Original Label: 276 | Target: 711 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 75/100 | Original Label: 292 | Target: 669 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 76/100 | Original Label: 77 | Target: 915 | Success: True | Distortion: 0.0314 | Iterations: 20
# Processed image 77/100 | Original Label: 927 | Target: 992 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 5
# Processed image 78/100 | Original Label: 892 | Target: 26 | Success: True | Distortion: 0.0235 | Iterations: 4
# Target class reached at iteration 10
# Processed image 79/100 | Original Label: 296 | Target: 902 | Success: True | Distortion: 0.0314 | Iterations: 9
# Processed image 80/100 | Original Label: 756 | Target: 257 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 12
# Processed image 81/100 | Original Label: 194 | Target: 373 | Success: True | Distortion: 0.0314 | Iterations: 11
# Processed image 82/100 | Original Label: 550 | Target: 220 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 11
# Processed image 83/100 | Original Label: 422 | Target: 643 | Success: True | Distortion: 0.0314 | Iterations: 10
# Processed image 84/100 | Original Label: 700 | Target: 338 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 85/100 | Original Label: 863 | Target: 780 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 6
# Processed image 86/100 | Original Label: 174 | Target: 159 | Success: True | Distortion: 0.0314 | Iterations: 5
# Target class reached at iteration 16
# Processed image 87/100 | Original Label: 158 | Target: 439 | Success: True | Distortion: 0.0314 | Iterations: 15
# Processed image 88/100 | Original Label: 688 | Target: 427 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 15
# Processed image 89/100 | Original Label: 33 | Target: 179 | Success: True | Distortion: 0.0314 | Iterations: 14
# Target class reached at iteration 7
# Processed image 90/100 | Original Label: 639 | Target: 374 | Success: True | Distortion: 0.0314 | Iterations: 6
# Processed image 91/100 | Original Label: 886 | Target: 986 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 13
# Processed image 92/100 | Original Label: 240 | Target: 145 | Success: True | Distortion: 0.0314 | Iterations: 12
# Target class reached at iteration 14
# Processed image 93/100 | Original Label: 785 | Target: 196 | Success: True | Distortion: 0.0314 | Iterations: 13
# Target class reached at iteration 16
# Processed image 94/100 | Original Label: 995 | Target: 982 | Success: True | Distortion: 0.0314 | Iterations: 15
# Processed image 95/100 | Original Label: 649 | Target: 182 | Success: False | Distortion: 0.0314 | Iterations: 20
# Processed image 96/100 | Original Label: 95 | Target: 482 | Success: True | Distortion: 0.0314 | Iterations: 20
# Processed image 97/100 | Original Label: 568 | Target: 580 | Success: False | Distortion: 0.0314 | Iterations: 20
# Target class reached at iteration 17
# Processed image 98/100 | Original Label: 508 | Target: 776 | Success: True | Distortion: 0.0314 | Iterations: 16
# Target class reached at iteration 15
# Processed image 99/100 | Original Label: 448 | Target: 280 | Success: True | Distortion: 0.0314 | Iterations: 14
# Processed image 100/100 | Original Label: 492 | Target: 321 | Success: False | Distortion: 0.0314 | Iterations: 20
#
# --- Evaluation Summary: Projected Gradient (Inception v3) ---
# Model: Adversarially Trained Inception v3
# Dataset: Validation Set (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 61.00%
# Average Iterations for all attacks: 15.25
# Average L-inf Distortion for all attacks: 0.0313
