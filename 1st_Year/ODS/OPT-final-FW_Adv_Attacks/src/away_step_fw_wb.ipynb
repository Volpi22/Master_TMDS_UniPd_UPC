# %%
import os
#
os.environ['PYTORCH_ENABLE_MPS_FALLBACK'] = '1'
import numpy as np
import random
import torch
import torch.nn as nn
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision import datasets
from transformers import AutoImageProcessor, AutoModelForImageClassification

import cifar_setup
import real_vs_fake_setup
import adversarially_trained_inception_setup

# %%
# Hyperparameters for the adversarial attack on CIFAR-10 dataset
parameters = {  
    "max_iterations": 20,
    "tolerance": 1e-6,
    "epsilon": 8/255,
}
# Defining the loss function for the adversarial attack
criterion = nn.CrossEntropyLoss()

# Function to compute the LMO for the adversarial attack
def LMO(gradient,epsilon):
    """
    Inputs:
        - gradient (torch.Tensor): The gradient of the objective function.
        - epsilon (float): The radius of the L-infinity ball.
    Output:
        - (torch.Tensor): The vertex s_t that maximizes the dot product with the gradient.
    """
    return epsilon * torch.sign(gradient)

# %%
def away_step_fw_wb(model, image, target, hyperparams):
    """
    Inputs:
        - model (nn.Module): The target neural network model.
        - image (torch.Tensor): The original input image (e.g., C, H, W).
        - target (torch.Tensor): The target class label for the attack (scalar).
        - hyperparams (dict): A dictionary of hyperparameters containing:
            - "max_iterations" (int): The maximum number of iterations.
            - "tolerance" (float): The duality gap tolerance for convergence.
            - "epsilon" (float): The L-infinity norm bound for the perturbation.
    Outputs:
        - final_adv_image (torch.Tensor): The generated adversarial image.
        - t (int): The number of iterations performed.
        - history (dict): A dictionary with the history of objective values, duality gaps, and gradient norms.
        - delta_t (torch.Tensor): The final perturbation added to the image.
    """
    # Setup device and move tensors
    device = next(model.parameters()).device
    image = image.to(device)
    target = target.to(device)

    # Defining the parameters
    max_iterations = hyperparams["max_iterations"]
    tolerance = hyperparams["tolerance"]
    epsilon = hyperparams["epsilon"]

    # Initialize the perturbation delta_t
    delta_t = torch.zeros_like(image, dtype=torch.float32, device=device)

    adv_img = image.clone().detach()

    # Defining the active set S and weights alpha_t
    active_set = [delta_t.clone()]
    weights = torch.tensor([1.0], device=device)

    # History trackers
    history = {'objective': [], 'gradient': [], 'gap': []}
    
    # Starting the Away-step Frank-Wolfe Iterations
    for t in range(1, max_iterations + 1):
        # Create the adversarial image by adding the perturbation
        adv_img.requires_grad = True

        # Forward pass through the model
        output = model(adv_img.unsqueeze(0))

        # Define the objective function to maximize: the negative cross-entropy loss
        loss = -criterion(output, target if target.dim() > 0 else target.unsqueeze(0))

        # Early stopping if attack is already successful
        with torch.no_grad():
            _, pred = torch.max(output, 1)
        if pred.item() == target.item():
            print(f"Target class reached at iteration {t}")
            break

        # Backward pass to get gradients
        model.zero_grad()
        loss.backward()
        grad_t = adv_img.grad.data

        # Compute the FW candidate direction
        s_t = LMO(grad_t, epsilon)
        d_t_FW = s_t - delta_t

        # Compute the duality gap
        gap_t_FW = (grad_t * d_t_FW).sum()

        # Compute the away vertex v_t
        v_t_idx = torch.argmin(torch.stack([torch.dot(v.view(-1), grad_t.view(-1)) for v in active_set]))
        v_t = active_set[v_t_idx]

        # Compute the Away-Step direction
        d_t_Away = delta_t - v_t
        gap_t_Away = (grad_t * d_t_Away).sum()

        # Store history
        history['gradient'].append(grad_t.norm().item())
        history['objective'].append(-loss.item())
        history['gap'].append(gap_t_FW.item() if gap_t_FW >= gap_t_Away else gap_t_Away.item())

        # Check for convergence
        if gap_t_FW <= tolerance:
            print(f"Duality gap below tolerance at iteration {t}: {gap_t_FW.item()}")
            break

        # Choose between Frank-Wolfe and Away-Step based on the duality gap
        if gap_t_FW >= gap_t_Away:
            selected_direction = "FW"
            selected_d_t = d_t_FW
            gamma_max = 1.0
        else:
            selected_direction = "Away-Step"
            selected_d_t = d_t_Away
            gamma_max = weights[v_t_idx] / (1.0 - weights[v_t_idx] + 1e-9)

        # search for the best step size gamma_t
        gamma_t = min(gamma_max, 2.0 / (t + 2.0))

        # Update the perturbation
        delta_t += gamma_t * selected_d_t

        # Update weights of the active set
        if selected_direction == "FW":
            if gamma_t == gamma_max:
                # Reset to just the current point
                active_set = [delta_t.clone()]
                weights = torch.tensor([1.0], device=device)
            else:
                is_in_active_set = any(torch.allclose(v, s_t, rtol=1e-5, atol=1e-5) for v in active_set)

                if not is_in_active_set:
                    active_set.append(s_t)
                    weights = torch.cat([weights, torch.tensor([gamma_t], device=device)])
                else:
                    s_t_idx = active_set.index(next(v for v in active_set if torch.allclose(v, s_t)))
                    weights = weights * (1.0 - gamma_t)
                    weights[s_t_idx] += gamma_t
        
        if selected_direction == "Away-Step":
            if gamma_t == gamma_max:
                # Convert to list first for proper deletion
                active_set.pop(v_t_idx)
                weights = torch.cat([weights[:v_t_idx], weights[v_t_idx+1:]])
            else:
                weights = weights * (1.0 + gamma_t)
                weights[v_t_idx] -= gamma_t
                
        # Remove vertices from the active set if their weights are effectively zero
        non_zero_indices = torch.where(weights > 1e-9)[0]
        if len(non_zero_indices) < len(weights):
            active_set = [active_set[i] for i in non_zero_indices]
            weights = weights[non_zero_indices]
            weights /= weights.sum()

        adv_img = (image + delta_t).detach()

    # Create the final adversarial image
    delta_t = adv_img - image

    return adv_img, t, history, delta_t

# %%
# Check if the script is running on macOS with Apple Silicon GPU (MPS) or on Windows/Linux with CUDA
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple Silicon GPU (MPS) on macOS.")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using NVIDIA/AMD GPU (CUDA) on Windows/Linux.")
else:
    device = torch.device("cpu")
    print("Using CPU as no GPU is available.")

print(f"Current device: {device}")

# 1. Load a pretrained ResNet50 model and set up the device
model = models.resnet50(weights=models.ResNet50_Weights.DEFAULT)
model.eval()
model.to(device)

# 2. Define image transformations for CIFAR-10 to be compatible with ResNet50
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# 3. Load CIFAR-10 test set
cifar10_test = datasets.CIFAR10(root='./data', train=False, download=True, transform=preprocess)
test_loader = torch.utils.data.DataLoader(cifar10_test, batch_size=1, shuffle=True)

# 4. Map CIFAR-10 classes to ImageNet indices, as ResNet50 is trained on ImageNet
cifar10_class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
cifar_to_imagenet = {
    'airplane': 404, 'automobile': 436, 'bird': 12, 'cat': 281, 'deer': 354,
    'dog': 207, 'frog': 30, 'horse': 339, 'ship': 780, 'truck': 867
}
cifar_idx_to_imagenet_idx = {i: cifar_to_imagenet[name] for i, name in enumerate(cifar10_class_names)}

# 5. Find or load 100 correctly classified images to use for the attack
correctly_classified_images = cifar_setup.get_correctly_classified_images(
    model=model,
    device=device,
    dataset_name='cifar10',
    num_images=100,
    model_name='resnet50'
)
# Out:
# Using Apple Silicon GPU (MPS) on macOS.
# Current device: mps
# 100%|██████████| 170M/170M [00:07<00:00, 22.2MB/s]
# Searching for 100 correctly classified images from CIFAR10...
# Found 100 correctly classified images.
# Saving images to ./data/correctly_classified_cifar10_resnet50.pt...
# Images saved.

# %%
# 6. Run the attack and evaluate
distortions = []
successful_attacks = 0
total_iterations = 0
images_attacked = 0
total_images_in_list = len(correctly_classified_images)
all_possible_targets = list(cifar_idx_to_imagenet_idx.values())

print(f"--- Starting Evaluation on {total_images_in_list} candidate images ---")
for i, (image, original_label) in enumerate(correctly_classified_images):
    
    # Verify that the model correctly classifies the image before the attack
    with torch.no_grad():
        initial_output = model(image.unsqueeze(0))
        _, initial_pred = torch.max(initial_output, 1)

    if initial_pred.item() != original_label.item():
        print(f"Skipping image {i+1}/{total_images_in_list}: Model misclassified it. (Pred: {initial_pred.item()}, Label: {original_label.item()})")
        continue
    
    images_attacked += 1

    # For a targeted attack, choose a random target class that is different from the original
    potential_targets = [t for t in all_possible_targets if t != original_label.item()]
    random_target_idx = random.choice(potential_targets)
    target_label = torch.tensor([random_target_idx], device=device)

    adv_image, n_iter, history, delta_final = away_step_fw_wb(
        model, image, target_label, parameters
    )

    with torch.no_grad():
        adv_output = model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions.append(distortion)
    total_iterations += n_iter
    
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 7. Calculate and print the final results
asr = (successful_attacks / images_attacked) * 100
avg_iterations = total_iterations / images_attacked
avg_distortion = np.mean(distortions)

print("\n--- Evaluation Summary Away-Step FW (CIFAR-10) ---")
print(f"Model: ResNet50")
print(f"Dataset: CIFAR-10 ({images_attacked} images attacked)")
print(f"Epsilon: {parameters['epsilon']:.4f}")
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations: {avg_iterations:.2f}")
print(f"Average L-inf Distortion: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images ---
# Target class reached at iteration 3
# Processed image 1/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 6
# Processed image 2/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 5
# Processed image 3/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 3
# Processed image 4/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 9
# Processed image 5/100 | Original Label: 404 | Target: 12 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 7
# Processed image 6/100 | Original Label: 207 | Target: 281 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 13
# Processed image 7/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 8
# Processed image 8/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 10
# Processed image 9/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0308 | Iterations: 10
# Target class reached at iteration 7
# Processed image 10/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 9
# Processed image 11/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0307 | Iterations: 9
# Processed image 12/100 | Original Label: 339 | Target: 436 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 8
# Processed image 13/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 8
# Processed image 14/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 5
# Processed image 15/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 6
# Processed image 16/100 | Original Label: 207 | Target: 281 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 12
# Processed image 17/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 12
# Target class reached at iteration 11
# Processed image 18/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0309 | Iterations: 11
# Target class reached at iteration 3
# Processed image 19/100 | Original Label: 404 | Target: 12 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 11
# Processed image 20/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0309 | Iterations: 11
# Target class reached at iteration 14
# Processed image 21/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0311 | Iterations: 14
# Target class reached at iteration 8
# Processed image 22/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 7
# Processed image 23/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 8
# Processed image 24/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 13
# Processed image 25/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 5
# Processed image 26/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 5
# Processed image 27/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 4
# Processed image 28/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 4
# Processed image 29/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 13
# Processed image 30/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 3
# Processed image 31/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 32/100 | Original Label: 404 | Target: 780 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 33/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 14
# Processed image 34/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0311 | Iterations: 14
# Target class reached at iteration 12
# Processed image 35/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 12
# Target class reached at iteration 13
# Processed image 36/100 | Original Label: 207 | Target: 436 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 3
# Processed image 37/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 38/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 4
# Processed image 39/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 9
# Processed image 40/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 4
# Processed image 41/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 8
# Processed image 42/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 4
# Processed image 43/100 | Original Label: 404 | Target: 207 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 44/100 | Original Label: 404 | Target: 780 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 7
# Processed image 45/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 13
# Processed image 46/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 4
# Processed image 47/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 4
# Processed image 48/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 5
# Processed image 49/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 5
# Processed image 50/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 7
# Processed image 51/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 8
# Processed image 52/100 | Original Label: 404 | Target: 780 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 8
# Processed image 53/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 4
# Processed image 54/100 | Original Label: 404 | Target: 207 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 7
# Processed image 55/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 8
# Processed image 56/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 4
# Processed image 57/100 | Original Label: 404 | Target: 339 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 58/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 11
# Processed image 59/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0309 | Iterations: 11
# Target class reached at iteration 2
# Processed image 60/100 | Original Label: 207 | Target: 12 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 7
# Processed image 61/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0303 | Iterations: 7
# Target class reached at iteration 6
# Processed image 62/100 | Original Label: 207 | Target: 780 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 4
# Processed image 63/100 | Original Label: 404 | Target: 207 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 4
# Processed image 64/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 10
# Processed image 65/100 | Original Label: 404 | Target: 867 | Success: True | Distortion: 0.0308 | Iterations: 10
# Target class reached at iteration 4
# Processed image 66/100 | Original Label: 207 | Target: 339 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 8
# Processed image 67/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 8
# Processed image 68/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0305 | Iterations: 8
# Target class reached at iteration 16
# Processed image 69/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0311 | Iterations: 16
# Target class reached at iteration 3
# Processed image 70/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 4
# Processed image 71/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 9
# Processed image 72/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 14
# Processed image 73/100 | Original Label: 339 | Target: 404 | Success: True | Distortion: 0.0311 | Iterations: 14
# Target class reached at iteration 5
# Processed image 74/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 4
# Processed image 75/100 | Original Label: 339 | Target: 207 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 5
# Processed image 76/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 9
# Processed image 77/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 4
# Processed image 78/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 5
# Processed image 79/100 | Original Label: 404 | Target: 30 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 3
# Processed image 80/100 | Original Label: 404 | Target: 12 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 5
# Processed image 81/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 9
# Processed image 82/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 16
# Processed image 83/100 | Original Label: 339 | Target: 436 | Success: True | Distortion: 0.0311 | Iterations: 16
# Target class reached at iteration 4
# Processed image 84/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 85/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 18
# Processed image 86/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0312 | Iterations: 18
# Target class reached at iteration 6
# Processed image 87/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0299 | Iterations: 6
# Processed image 88/100 | Original Label: 339 | Target: 436 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 2
# Processed image 89/100 | Original Label: 339 | Target: 354 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 9
# Processed image 90/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0307 | Iterations: 9
# Target class reached at iteration 6
# Processed image 91/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 4
# Processed image 92/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 6
# Processed image 93/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 4
# Processed image 94/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 95/100 | Original Label: 339 | Target: 12 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 5
# Processed image 96/100 | Original Label: 339 | Target: 281 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 4
# Processed image 97/100 | Original Label: 354 | Target: 12 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 10
# Processed image 98/100 | Original Label: 339 | Target: 780 | Success: True | Distortion: 0.0308 | Iterations: 10
# Target class reached at iteration 12
# Processed image 99/100 | Original Label: 339 | Target: 867 | Success: True | Distortion: 0.0310 | Iterations: 12
# Target class reached at iteration 11
# Processed image 100/100 | Original Label: 339 | Target: 30 | Success: True | Distortion: 0.0309 | Iterations: 11
#
# --- Evaluation Summary Away-Step FW (CIFAR-10) ---
# Model: ResNet50
# Dataset: CIFAR-10 (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 98.00%
# Average Iterations: 7.20
# Average L-inf Distortion: 0.0292

# %%
# Check for device
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# 1. Load the real-vs-fake model and processor
rvf_model_name = "dima806/ai_vs_real_image_detection"
rvf_processor = AutoImageProcessor.from_pretrained(rvf_model_name)
rvf_model = AutoModelForImageClassification.from_pretrained(rvf_model_name)
rvf_model.to(device)
rvf_model.eval()

# 2. Define the path to your test dataset
test_dataset_path = '/Users/gianfranco/Desktop/ODS/test'  # Replace with your actual path. The dataset can be downloaded from https://www.kaggle.com/code/dima806/cifake-ai-generated-image-detection-vit/input


# 3. Find or load 1000 correctly classified images
# This will test the function you created in real-vs-fake_setup.py
correctly_classified_rvf_images = real_vs_fake_setup.get_correctly_classified_images_real_vs_fake(
    model=rvf_model,
    processor=rvf_processor,
    device=device,
    dataset_path=test_dataset_path,
    num_images=100
)

print(f"\nRetrieved {len(correctly_classified_rvf_images)} correctly classified real-vs-fake images.")
# Out:
# Using device: mps
# Loading correctly classified images from ./data/correctly_classified_real_vs_fake_dima806_ai_vs_real_image_detection.pt...
# Loaded 100 images.
#
# Retrieved 100 correctly classified real-vs-fake images.

# %%
# 4. Run the attack and evaluate on the Real-vs-Fake dataset

# Wrapper to make the Hugging Face model compatible with the existing attack function and ensures the model output is a tensor of logits
class ModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model
    def forward(self, x):
        return self.model(x).logits

wrapped_rvf_model = ModelWrapper(rvf_model)

distortions_rvf = []
successful_attacks_rvf = 0
total_iterations_rvf = 0
images_attacked_rvf = 0
total_images_in_list = len(correctly_classified_rvf_images)

print(f"--- Starting Evaluation on {total_images_in_list} candidate images (Real-vs-Fake) ---")

for i, (image, original_label) in enumerate(correctly_classified_rvf_images):
    
    # Move tensors to the correct device for the current model
    image = image.to(device)
    original_label = original_label.to(device)

    # First, verify that the model correctly classifies the image before the attack
    with torch.no_grad():
        initial_output = wrapped_rvf_model(image.unsqueeze(0))
        _, initial_pred = torch.max(initial_output, 1)

    if initial_pred.item() != original_label.item():
        print(f"Skipping image {i+1}/{total_images_in_list}: Model misclassified it. (Pred: {initial_pred.item()}, Label: {original_label.item()})")
        continue
    
    images_attacked_rvf += 1

    # For a targeted attack, the target is the other class (0 -> 1, 1 -> 0)
    target_label_idx = 1 - original_label.item()
    target_label = torch.tensor([target_label_idx], device=device)

    adv_image, n_iter, history, delta_final = away_step_fw_wb(
        wrapped_rvf_model, image, target_label, parameters
    )

    with torch.no_grad():
        adv_output = wrapped_rvf_model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks_rvf += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions_rvf.append(distortion)
    total_iterations_rvf += n_iter
    
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 5. Calculate and print the final results
asr = (successful_attacks_rvf / images_attacked_rvf) * 100
avg_iterations = total_iterations_rvf / images_attacked_rvf
avg_distortion = np.mean(distortions_rvf)

print("\n--- Evaluation Summary Away Step FW (Real-vs-Fake) ---")
print(f"Model: {rvf_model_name}")
print(f"Dataset: Real-vs-Fake ({images_attacked_rvf} images attacked)")
print(f"Epsilon: {parameters['epsilon']:.4f}")
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations: {avg_iterations:.2f}")
print(f"Average L-inf Distortion: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images (Real-vs-Fake) ---
# Target class reached at iteration 3
# Processed image 1/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 2/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 3/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 4/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 4
# Processed image 5/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 2
# Processed image 6/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 5
# Processed image 7/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0293 | Iterations: 5
# Target class reached at iteration 2
# Processed image 8/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 9/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 10/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 11/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 12/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 13/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 14/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 15/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 16/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 2
# Processed image 17/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 18/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 19/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 20/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 21/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 22/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 23/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 24/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 25/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 26/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 27/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 28/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 29/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 30/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 31/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 32/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 33/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 34/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 35/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 36/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 37/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 38/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 39/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 40/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 41/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 42/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 43/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 44/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 45/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 46/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 47/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 48/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 49/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 50/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 51/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 52/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 53/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 54/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 55/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 56/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 6
# Processed image 57/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0299 | Iterations: 6
# Target class reached at iteration 2
# Processed image 58/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 59/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 60/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 61/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 62/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 63/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 64/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 65/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 66/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 67/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 2
# Processed image 68/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 69/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 70/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 71/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 2
# Processed image 72/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 73/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 74/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 75/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 76/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 77/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 78/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 79/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 80/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 81/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 3
# Processed image 82/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 83/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 84/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 85/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 86/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 87/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 88/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 89/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 90/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 91/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 2
# Processed image 92/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 93/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 3
# Processed image 94/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 95/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 96/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 2
# Processed image 97/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 3
# Processed image 98/100 | Original Label: 1 | Target: 0 | Success: True | Distortion: 0.0261 | Iterations: 3
# Target class reached at iteration 2
# Processed image 99/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0209 | Iterations: 2
# Target class reached at iteration 4
# Processed image 100/100 | Original Label: 0 | Target: 1 | Success: True | Distortion: 0.0282 | Iterations: 4
#
# --- Evaluation Summary Away Step FW (Real-vs-Fake) ---
# Model: dima806/ai_vs_real_image_detection
# Dataset: Real-vs-Fake (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 100.00%
# Average Iterations: 2.42
# Average L-inf Distortion: 0.0227

# %%
# 1. Set up the device (MPS, CUDA, or CPU)
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Using Apple Silicon GPU (MPS)")
elif torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using NVIDIA GPU (CUDA)")
else:
    device = torch.device("cpu")
    print("Using CPU")

# 2. Load the Adversarially Trained Inception v3 model
model = adversarially_trained_inception_setup.get_model(device)
model.eval()

# 3. Load the validation dataset
# The path is hardcoded in the setup script, but can be overridden
dataset = adversarially_trained_inception_setup.get_dataset()

# 4. Find correctly classified images to attack
# This will be our test set for the attack evaluation
correctly_classified_images = adversarially_trained_inception_setup.get_correctly_classified_images(
    model=model,
    device=device,
    dataset=dataset,
    num_images=100
)
# Out:
# Using Apple Silicon GPU (MPS)
# Finding model-classified images: 100%|██████████| 100/100 [00:08<00:00, 12.33it/s]
# Found 100 images to attack.

# %%
# 5. Run the attack and evaluate
distortions = []
successful_attacks = 0
total_iterations = 0
images_attacked = 0
total_images_in_list = len(correctly_classified_images)

# The Inception v3 model was trained on ImageNet, which has 1000 classes
num_classes = 1000
all_possible_targets = list(range(num_classes))

print(f"\n--- Starting Evaluation on {total_images_in_list} candidate images ---")

for i, (image, original_label) in enumerate(correctly_classified_images):
    image, original_label = image.to(device), original_label.to(device)
    
    images_attacked += 1

    # For a targeted attack, choose a random target class that is different from the original
    potential_targets = [t for t in all_possible_targets if t != original_label.item()]
        
    random_target_idx = random.choice(potential_targets)
    target_label = torch.tensor([random_target_idx], device=device)

    # Run the attack
    adv_image, n_iter, history, delta_final = away_step_fw_wb(
        model, image.squeeze(0), target_label, parameters
    )

    # Check if the attack was successful
    with torch.no_grad():
        adv_output = model(adv_image.unsqueeze(0))
        _, adv_pred = torch.max(adv_output, 1)

    is_success = adv_pred.item() == target_label.item()
    if is_success:
        successful_attacks += 1

    distortion = torch.max(torch.abs(delta_final)).item()
    distortions.append(distortion)
    total_iterations += n_iter
    
    # Add the detailed print statement you requested
    print(f"Processed image {i+1}/{total_images_in_list} | Original Label: {original_label.item()} | Target: {target_label.item()} | Success: {is_success} | Distortion: {distortion:.4f} | Iterations: {n_iter}")

# 6. Calculate and print the final results
asr = (successful_attacks / images_attacked) * 100
avg_iterations = total_iterations / images_attacked if total_iterations > 0 else 0
avg_distortion = np.mean(distortions) if distortions else 0

print("\n--- Evaluation Summary: Away Step FW (Inception v3) ---")
print(f"Model: Adversarially Trained Inception v3")
print(f"Dataset: Validation Set ({images_attacked} images attacked)")
print(f"Epsilon: {parameters['epsilon']:.4f}")
print("-" * 35)
print(f"Attack Success Rate (ASR): {asr:.2f}%")
print(f"Average Iterations for all attacks: {avg_iterations:.2f}")
print(f"Average L-inf Distortion for all attacks: {avg_distortion:.4f}")
# Out:
# --- Starting Evaluation on 100 candidate images ---
# Target class reached at iteration 7
# Processed image 1/100 | Original Label: 737 | Target: 918 | Success: True | Distortion: 0.0303 | Iterations: 7
# Processed image 2/100 | Original Label: 321 | Target: 256 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 6
# Processed image 3/100 | Original Label: 919 | Target: 714 | Success: True | Distortion: 0.0299 | Iterations: 6
# Processed image 4/100 | Original Label: 229 | Target: 807 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 5/100 | Original Label: 789 | Target: 692 | Success: True | Distortion: 0.0312 | Iterations: 18
# Processed image 6/100 | Original Label: 637 | Target: 982 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 11
# Processed image 7/100 | Original Label: 504 | Target: 843 | Success: True | Distortion: 0.0309 | Iterations: 11
# Target class reached at iteration 11
# Processed image 8/100 | Original Label: 529 | Target: 155 | Success: True | Distortion: 0.0309 | Iterations: 11
# Processed image 9/100 | Original Label: 405 | Target: 111 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 10/100 | Original Label: 619 | Target: 119 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 11/100 | Original Label: 939 | Target: 121 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 12/100 | Original Label: 261 | Target: 89 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 13/100 | Original Label: 850 | Target: 404 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 14/100 | Original Label: 36 | Target: 807 | Success: True | Distortion: 0.0312 | Iterations: 18
# Processed image 15/100 | Original Label: 332 | Target: 417 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 16/100 | Original Label: 632 | Target: 775 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 17/100 | Original Label: 132 | Target: 304 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 18/100 | Original Label: 489 | Target: 549 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 19/100 | Original Label: 948 | Target: 689 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 20/100 | Original Label: 480 | Target: 74 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 19
# Processed image 21/100 | Original Label: 798 | Target: 542 | Success: True | Distortion: 0.0312 | Iterations: 19
# Target class reached at iteration 16
# Processed image 22/100 | Original Label: 764 | Target: 467 | Success: True | Distortion: 0.0311 | Iterations: 16
# Processed image 23/100 | Original Label: 966 | Target: 37 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 14
# Processed image 24/100 | Original Label: 951 | Target: 712 | Success: True | Distortion: 0.0311 | Iterations: 14
# Processed image 25/100 | Original Label: 369 | Target: 426 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 26/100 | Original Label: 679 | Target: 907 | Success: True | Distortion: 0.0312 | Iterations: 18
# Target class reached at iteration 13
# Processed image 27/100 | Original Label: 972 | Target: 916 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 6
# Processed image 28/100 | Original Label: 272 | Target: 141 | Success: True | Distortion: 0.0299 | Iterations: 6
# Processed image 29/100 | Original Label: 681 | Target: 505 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 30/100 | Original Label: 800 | Target: 413 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 31/100 | Original Label: 44 | Target: 610 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 32/100 | Original Label: 618 | Target: 791 | Success: True | Distortion: 0.0312 | Iterations: 18
# Target class reached at iteration 11
# Processed image 33/100 | Original Label: 999 | Target: 827 | Success: True | Distortion: 0.0309 | Iterations: 11
# Target class reached at iteration 17
# Processed image 34/100 | Original Label: 304 | Target: 129 | Success: True | Distortion: 0.0312 | Iterations: 17
# Target class reached at iteration 15
# Processed image 35/100 | Original Label: 158 | Target: 842 | Success: True | Distortion: 0.0311 | Iterations: 15
# Processed image 36/100 | Original Label: 935 | Target: 349 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 37/100 | Original Label: 23 | Target: 250 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 17
# Processed image 38/100 | Original Label: 819 | Target: 368 | Success: True | Distortion: 0.0312 | Iterations: 17
# Target class reached at iteration 13
# Processed image 39/100 | Original Label: 241 | Target: 771 | Success: True | Distortion: 0.0310 | Iterations: 13
# Processed image 40/100 | Original Label: 611 | Target: 115 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 10
# Processed image 41/100 | Original Label: 68 | Target: 911 | Success: True | Distortion: 0.0308 | Iterations: 10
# Target class reached at iteration 13
# Processed image 42/100 | Original Label: 784 | Target: 725 | Success: True | Distortion: 0.0310 | Iterations: 13
# Processed image 43/100 | Original Label: 665 | Target: 702 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 44/100 | Original Label: 491 | Target: 272 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 45/100 | Original Label: 310 | Target: 20 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 46/100 | Original Label: 765 | Target: 594 | Success: True | Distortion: 0.0312 | Iterations: 18
# Target class reached at iteration 19
# Processed image 47/100 | Original Label: 939 | Target: 378 | Success: True | Distortion: 0.0312 | Iterations: 19
# Target class reached at iteration 12
# Processed image 48/100 | Original Label: 505 | Target: 605 | Success: True | Distortion: 0.0310 | Iterations: 12
# Target class reached at iteration 10
# Processed image 49/100 | Original Label: 663 | Target: 611 | Success: True | Distortion: 0.0308 | Iterations: 10
# Processed image 50/100 | Original Label: 581 | Target: 607 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 51/100 | Original Label: 919 | Target: 55 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 52/100 | Original Label: 801 | Target: 132 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 4
# Processed image 53/100 | Original Label: 878 | Target: 507 | Success: True | Distortion: 0.0282 | Iterations: 4
# Processed image 54/100 | Original Label: 458 | Target: 125 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 55/100 | Original Label: 651 | Target: 31 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 19
# Processed image 56/100 | Original Label: 737 | Target: 808 | Success: True | Distortion: 0.0312 | Iterations: 19
# Target class reached at iteration 19
# Processed image 57/100 | Original Label: 285 | Target: 426 | Success: True | Distortion: 0.0312 | Iterations: 19
# Processed image 58/100 | Original Label: 915 | Target: 939 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 59/100 | Original Label: 701 | Target: 256 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 19
# Processed image 60/100 | Original Label: 238 | Target: 854 | Success: True | Distortion: 0.0312 | Iterations: 19
# Processed image 61/100 | Original Label: 88 | Target: 375 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 62/100 | Original Label: 681 | Target: 251 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 63/100 | Original Label: 854 | Target: 22 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 16
# Processed image 64/100 | Original Label: 245 | Target: 722 | Success: True | Distortion: 0.0311 | Iterations: 16
# Processed image 65/100 | Original Label: 848 | Target: 351 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 66/100 | Original Label: 71 | Target: 196 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 14
# Processed image 67/100 | Original Label: 305 | Target: 342 | Success: True | Distortion: 0.0311 | Iterations: 14
# Target class reached at iteration 11
# Processed image 68/100 | Original Label: 298 | Target: 635 | Success: True | Distortion: 0.0309 | Iterations: 11
# Processed image 69/100 | Original Label: 859 | Target: 542 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 70/100 | Original Label: 945 | Target: 914 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 71/100 | Original Label: 294 | Target: 815 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 12
# Processed image 72/100 | Original Label: 232 | Target: 910 | Success: True | Distortion: 0.0310 | Iterations: 12
# Target class reached at iteration 19
# Processed image 73/100 | Original Label: 654 | Target: 195 | Success: True | Distortion: 0.0312 | Iterations: 19
# Target class reached at iteration 13
# Processed image 74/100 | Original Label: 971 | Target: 524 | Success: True | Distortion: 0.0310 | Iterations: 13
# Processed image 75/100 | Original Label: 224 | Target: 771 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 13
# Processed image 76/100 | Original Label: 345 | Target: 868 | Success: True | Distortion: 0.0310 | Iterations: 13
# Target class reached at iteration 5
# Processed image 77/100 | Original Label: 900 | Target: 915 | Success: True | Distortion: 0.0293 | Iterations: 5
# Processed image 78/100 | Original Label: 911 | Target: 301 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 9
# Processed image 79/100 | Original Label: 218 | Target: 39 | Success: True | Distortion: 0.0307 | Iterations: 9
# Processed image 80/100 | Original Label: 594 | Target: 917 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 81/100 | Original Label: 22 | Target: 573 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 82/100 | Original Label: 607 | Target: 886 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 17
# Processed image 83/100 | Original Label: 241 | Target: 932 | Success: True | Distortion: 0.0312 | Iterations: 17
# Target class reached at iteration 4
# Processed image 84/100 | Original Label: 717 | Target: 819 | Success: True | Distortion: 0.0282 | Iterations: 4
# Target class reached at iteration 16
# Processed image 85/100 | Original Label: 768 | Target: 818 | Success: True | Distortion: 0.0311 | Iterations: 16
# Processed image 86/100 | Original Label: 864 | Target: 438 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 20
# Processed image 87/100 | Original Label: 870 | Target: 936 | Success: True | Distortion: 0.0312 | Iterations: 20
# Processed image 88/100 | Original Label: 596 | Target: 197 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 14
# Processed image 89/100 | Original Label: 946 | Target: 180 | Success: True | Distortion: 0.0311 | Iterations: 14
# Processed image 90/100 | Original Label: 278 | Target: 737 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 15
# Processed image 91/100 | Original Label: 124 | Target: 52 | Success: True | Distortion: 0.0311 | Iterations: 15
# Processed image 92/100 | Original Label: 846 | Target: 326 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 17
# Processed image 93/100 | Original Label: 481 | Target: 850 | Success: True | Distortion: 0.0312 | Iterations: 17
# Processed image 94/100 | Original Label: 48 | Target: 506 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 18
# Processed image 95/100 | Original Label: 926 | Target: 615 | Success: True | Distortion: 0.0312 | Iterations: 18
# Target class reached at iteration 14
# Processed image 96/100 | Original Label: 504 | Target: 130 | Success: True | Distortion: 0.0311 | Iterations: 14
# Processed image 97/100 | Original Label: 374 | Target: 519 | Success: False | Distortion: 0.0312 | Iterations: 20
# Target class reached at iteration 20
# Processed image 98/100 | Original Label: 577 | Target: 193 | Success: True | Distortion: 0.0312 | Iterations: 20
# Processed image 99/100 | Original Label: 607 | Target: 863 | Success: False | Distortion: 0.0312 | Iterations: 20
# Processed image 100/100 | Original Label: 778 | Target: 231 | Success: False | Distortion: 0.0312 | Iterations: 20
#
# --- Evaluation Summary: Away Step FW (Inception v3) ---
# Model: Adversarially Trained Inception v3
# Dataset: Validation Set (100 images attacked)
# Epsilon: 0.0314
# -----------------------------------
# Attack Success Rate (ASR): 47.00%
# Average Iterations for all attacks: 17.18
# Average L-inf Distortion for all attacks: 0.0311
